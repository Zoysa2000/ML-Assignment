# %%
import pandas as pd
df = pd.read_csv('Downloads\healthcare-dataset-stroke-data.csv')
df.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
df_no_id = df.drop('id', axis=1)

# %%
df_no_id.head()
# Out:
#    gender   age  hypertension  heart_disease ever_married      work_type  \
# 0    Male  67.0             0              1          Yes        Private
# 1  Female  61.0             0              0          Yes  Self-employed
# 2    Male  80.0             0              1          Yes        Private
# 3  Female  49.0             0              0          Yes        Private
# 4  Female  79.0             1              0          Yes  Self-employed
#
#   Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# 0          Urban             228.69  36.6  formerly smoked       1
# 1          Rural             202.21   NaN     never smoked       1
# 2          Rural             105.92  32.5     never smoked       1
# 3          Urban             171.23  34.4           smokes       1
# 4          Rural             174.12  24.0     never smoked       1

# %%
df_no_id['gender'] = df_no_id['gender'].map({'Male': 1, 'Female': 0}).fillna(0).astype(int)

# %%
df_no_id.head()
# Out:
#    gender   age  hypertension  heart_disease ever_married      work_type  \
# 0       1  67.0             0              1          Yes        Private
# 1       0  61.0             0              0          Yes  Self-employed
# 2       1  80.0             0              1          Yes        Private
# 3       0  49.0             0              0          Yes        Private
# 4       0  79.0             1              0          Yes  Self-employed
#
#   Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# 0          Urban             228.69  36.6  formerly smoked       1
# 1          Rural             202.21   NaN     never smoked       1
# 2          Rural             105.92  32.5     never smoked       1
# 3          Urban             171.23  34.4           smokes       1
# 4          Rural             174.12  24.0     never smoked       1

# %%
df_no_id.tail()
# Out:
#       gender   age  hypertension  heart_disease ever_married      work_type  \
# 5105       0  80.0             1              0          Yes        Private
# 5106       0  81.0             0              0          Yes  Self-employed
# 5107       0  35.0             0              0          Yes  Self-employed
# 5108       1  51.0             0              0          Yes        Private
# 5109       0  44.0             0              0          Yes       Govt_job
#
#      Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# 5105          Urban              83.75   NaN     never smoked       0
# 5106          Urban             125.20  40.0     never smoked       0
# 5107          Rural              82.99  30.6     never smoked       0
# 5108          Rural             166.29  25.6  formerly smoked       0
# 5109          Urban              85.28  26.2          Unknown       0

# %%
df_no_id['age'] = df_no_id['age'].astype(int)

# %%
df_no_id.head()
# Out:
#    gender  age  hypertension  heart_disease ever_married      work_type  \
# 0       1   67             0              1          Yes        Private
# 1       0   61             0              0          Yes  Self-employed
# 2       1   80             0              1          Yes        Private
# 3       0   49             0              0          Yes        Private
# 4       0   79             1              0          Yes  Self-employed
#
#   Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# 0          Urban             228.69  36.6  formerly smoked       1
# 1          Rural             202.21   NaN     never smoked       1
# 2          Rural             105.92  32.5     never smoked       1
# 3          Urban             171.23  34.4           smokes       1
# 4          Rural             174.12  24.0     never smoked       1

# %%
df_no_id
# Out:
#       gender  age  hypertension  heart_disease ever_married      work_type  \
# 0          1   67             0              1          Yes        Private
# 1          0   61             0              0          Yes  Self-employed
# 2          1   80             0              1          Yes        Private
# 3          0   49             0              0          Yes        Private
# 4          0   79             1              0          Yes  Self-employed
# ...      ...  ...           ...            ...          ...            ...
# 5105       0   80             1              0          Yes        Private
# 5106       0   81             0              0          Yes  Self-employed
# 5107       0   35             0              0          Yes  Self-employed
# 5108       1   51             0              0          Yes        Private
# 5109       0   44             0              0          Yes       Govt_job
#
# ...

# %%
average_age = df_no_id.loc[df_no_id['age'] > 18, 'age'].mean()

# Replace ages between 1 and 18 with the calculated average
df_no_id.loc[df_no_id['age'].between(1, 18), 'age'] = average_age

# Convert age column to integer if needed
df_no_id['age'] = df_no_id['age'].astype(int)

# Verify changes
df_no_id.head()
# Out:
# C:\Users\#DeZoysa\AppData\Local\Temp\ipykernel_10896\4121254460.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '50.66285169289461' has dtype incompatible with int32, please explicitly cast to a compatible dtype first.
#   df_no_id.loc[df_no_id['age'].between(1, 18), 'age'] = average_age
#    gender  age  hypertension  heart_disease ever_married      work_type  \
# 0       1   67             0              1          Yes        Private
# 1       0   61             0              0          Yes  Self-employed
# 2       1   80             0              1          Yes        Private
# 3       0   49             0              0          Yes        Private
# 4       0   79             1              0          Yes  Self-employed
#
#   Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# 0          Urban             228.69  36.6  formerly smoked       1
# ...

# %%
df_no_id.iloc[3089:3099]
# Out:
#       gender  age  hypertension  heart_disease ever_married work_type  \
# 3089       0   38             1              0          Yes   Private
# 3090       0   50             0              0          Yes  Govt_job
# 3091       0   75             0              0          Yes   Private
# 3092       0   50             0              0           No  children
# 3093       1   32             0              0          Yes   Private
# 3094       1   50             0              0           No  children
# 3095       1   32             0              0           No   Private
# 3096       0   50             0              0           No  children
# 3097       1   50             0              0           No  children
# 3098       0   63             0              0          Yes   Private
#
#      Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# 3089          Rural             109.46  41.5     never smoked       0
# ...

# %%
df_no_id.head()
# Out:
#    gender  age  hypertension  heart_disease ever_married      work_type  \
# 0       1   67             0              1          Yes        Private
# 1       0   61             0              0          Yes  Self-employed
# 2       1   80             0              1          Yes        Private
# 3       0   49             0              0          Yes        Private
# 4       0   79             1              0          Yes  Self-employed
#
#   Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# 0          Urban             228.69  36.6  formerly smoked       1
# 1          Rural             202.21   NaN     never smoked       1
# 2          Rural             105.92  32.5     never smoked       1
# 3          Urban             171.23  34.4           smokes       1
# 4          Rural             174.12  24.0     never smoked       1

# %%
df_no_id['ever_married'] = df_no_id['ever_married'].map({'Yes': 1, 'No': 0})

df_no_id.head()
# Out:
#    gender  age  hypertension  heart_disease  ever_married      work_type  \
# 0       1   67             0              1             1        Private
# 1       0   61             0              0             1  Self-employed
# 2       1   80             0              1             1        Private
# 3       0   49             0              0             1        Private
# 4       0   79             1              0             1  Self-employed
#
#   Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# 0          Urban             228.69  36.6  formerly smoked       1
# 1          Rural             202.21   NaN     never smoked       1
# 2          Rural             105.92  32.5     never smoked       1
# 3          Urban             171.23  34.4           smokes       1
# 4          Rural             174.12  24.0     never smoked       1

# %%
df_no_id['work_type'] = df_no_id['work_type'].map({
    'Private': 1,
    'Govt_job': 2,
    'Self-employed': 3
})

# %%
most_common_work_type = df_no_id['work_type'].mode()[0]

# %%
df_no_id['work_type'] = df_no_id['work_type'].replace('children', most_common_work_type)

# %%
df_no_id['work_type'] = df_no_id['work_type'].fillna(0).astype(int)

# %%
df_no_id
# Out:
#       gender  age  hypertension  heart_disease  ever_married  work_type  \
# 0          1   67             0              1             1          1
# 1          0   61             0              0             1          3
# 2          1   80             0              1             1          1
# 3          0   49             0              0             1          1
# 4          0   79             1              0             1          3
# ...      ...  ...           ...            ...           ...        ...
# 5105       0   80             1              0             1          1
# 5106       0   81             0              0             1          3
# 5107       0   35             0              0             1          3
# 5108       1   51             0              0             1          1
# 5109       0   44             0              0             1          2
#
#      Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# ...

# %%
df_no_id.iloc[5030:5035]
# Out:
#       gender  age  hypertension  heart_disease  ever_married  work_type  \
# 5030       1   21             0              0             1          1
# 5031       0   20             0              0             0          1
# 5032       0   50             0              0             0          0
# 5033       0   26             0              0             0          1
# 5034       0   79             0              0             0          1
#
#      Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# 5030          Rural              77.42  24.8     never smoked       0
# 5031          Rural             117.59  17.1     never smoked       0
# 5032          Rural              61.94  20.3          Unknown       0
# 5033          Urban             116.68  18.7  formerly smoked       0
# 5034          Urban             253.86  28.8  formerly smoked       0

# %%
df_no_id['Residence_type'] = df_no_id['Residence_type'].map({'Urban': 1, 'Rural': 2})
df_no_id.rename(columns={"Residence_type": "residence_type"}, inplace=True)

# %%
df_no_id.head()
# Out:
#    gender  age  hypertension  heart_disease  ever_married  work_type  \
# 0       1   67             0              1             1          1
# 1       0   61             0              0             1          3
# 2       1   80             0              1             1          1
# 3       0   49             0              0             1          1
# 4       0   79             1              0             1          3
#
#    residence_type  avg_glucose_level   bmi   smoking_status  stroke
# 0               1             228.69  36.6  formerly smoked       1
# 1               2             202.21   NaN     never smoked       1
# 2               2             105.92  32.5     never smoked       1
# 3               1             171.23  34.4           smokes       1
# 4               2             174.12  24.0     never smoked       1

# %%
df_no_id['avg_glucose_level'] = df_no_id['avg_glucose_level'].fillna(0).astype(int)

# %%
df_no_id.head()
# Out:
#    gender  age  hypertension  heart_disease  ever_married  work_type  \
# 0       1   67             0              1             1          1
# 1       0   61             0              0             1          3
# 2       1   80             0              1             1          1
# 3       0   49             0              0             1          1
# 4       0   79             1              0             1          3
#
#    residence_type  avg_glucose_level   bmi   smoking_status  stroke
# 0               1                228  36.6  formerly smoked       1
# 1               2                202   NaN     never smoked       1
# 2               2                105  32.5     never smoked       1
# 3               1                171  34.4           smokes       1
# 4               2                174  24.0     never smoked       1

# %%
# Calculate mean of 'bmi' (excluding NaNs)
mean_bmi = df_no_id['bmi'].mean()

# Replace NaN with mean
df_no_id['bmi'] = df_no_id['bmi'].fillna(mean_bmi)

# %%
df_no_id['bmi'] = df_no_id['bmi'].astype(int)

# %%
df_no_id.head()
# Out:
#    gender  age  hypertension  heart_disease  ever_married  work_type  \
# 0       1   67             0              1             1          1
# 1       0   61             0              0             1          3
# 2       1   80             0              1             1          1
# 3       0   49             0              0             1          1
# 4       0   79             1              0             1          3
#
#    residence_type  avg_glucose_level  bmi   smoking_status  stroke
# 0               1                228   36  formerly smoked       1
# 1               2                202   28     never smoked       1
# 2               2                105   32     never smoked       1
# 3               1                171   34           smokes       1
# 4               2                174   24     never smoked       1

# %%
df_no_id.iloc[1860:1869]
# Out:
#       gender  age  hypertension  heart_disease  ever_married  work_type  \
# 1860       1   63             0              0             1          1
# 1861       0   45             0              0             1          1
# 1862       0   53             1              1             1          1
# 1863       0   50             0              0             0          0
# 1864       0   56             0              0             1          1
# 1865       0   29             0              0             1          1
# 1866       1   50             0              0             0          0
# 1867       0   55             0              0             1          1
# 1868       0   49             0              0             1          2
#
#       residence_type  avg_glucose_level  bmi   smoking_status  stroke
# 1860               1                 92   35  formerly smoked       0
# 1861               1                115   28     never smoked       0
# ...

# %%
df_no_id['smoking_status'] = df_no_id['smoking_status'].replace({
    'formerly smoked': 1,
    'never smoked': 2,
    'smokes': 3
})

# %%
most_common_smoking = df_no_id['smoking_status'].mode()[0]

# Replace 'Unknown' with mode
df_no_id['smoking_status'] = df_no_id['smoking_status'].replace('Unknown', most_common_smoking)

# Optional: convert to int type
df_no_id['smoking_status'] = df_no_id['smoking_status'].astype(int)
# Out:
# C:\Users\#DeZoysa\AppData\Local\Temp\ipykernel_10896\266242131.py:4: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_no_id['smoking_status'] = df_no_id['smoking_status'].replace('Unknown', most_common_smoking)

# %%
df_no_id
# Out:
#       gender  age  hypertension  heart_disease  ever_married  work_type  \
# 0          1   67             0              1             1          1
# 1          0   61             0              0             1          3
# 2          1   80             0              1             1          1
# 3          0   49             0              0             1          1
# 4          0   79             1              0             1          3
# ...      ...  ...           ...            ...           ...        ...
# 5105       0   80             1              0             1          1
# 5106       0   81             0              0             1          3
# 5107       0   35             0              0             1          3
# 5108       1   51             0              0             1          1
# 5109       0   44             0              0             1          2
#
#       residence_type  avg_glucose_level  bmi  smoking_status  stroke
# ...

# %%
df_no_id.iloc[1:11]
# Out:
#     gender  age  hypertension  heart_disease  ever_married  work_type  \
# 1        0   61             0              0             1          3
# 2        1   80             0              1             1          1
# 3        0   49             0              0             1          1
# 4        0   79             1              0             1          3
# 5        1   81             0              0             1          1
# 6        1   74             1              1             1          1
# 7        0   69             0              0             0          1
# 8        0   59             0              0             1          1
# 9        0   78             0              0             1          1
# 10       0   81             1              0             1          1
#
#     residence_type  avg_glucose_level  bmi  smoking_status  stroke
# 1                2                202   28               2       1
# ...

# %%
df_no_id
# Out:
#       gender  age  hypertension  heart_disease  ever_married  work_type  \
# 0          1   67             0              1             1          1
# 1          0   61             0              0             1          3
# 2          1   80             0              1             1          1
# 3          0   49             0              0             1          1
# 4          0   79             1              0             1          3
# ...      ...  ...           ...            ...           ...        ...
# 5105       0   80             1              0             1          1
# 5106       0   81             0              0             1          3
# 5107       0   35             0              0             1          3
# 5108       1   51             0              0             1          1
# 5109       0   44             0              0             1          2
#
#       residence_type  avg_glucose_level  bmi  smoking_status  stroke
# ...

# %%
df_no_id[['avg_glucose_level', 'bmi']].describe()
# Out:
#        avg_glucose_level          bmi
# count        5110.000000  5110.000000
# mean          105.658317    28.430920
# std            45.275290     7.688483
# min            55.000000    10.000000
# 25%            77.000000    23.000000
# 50%            91.000000    28.000000
# 75%           114.000000    32.000000
# max           271.000000    97.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(12, 5))

# Histogram for avg_glucose_level
plt.subplot(1, 2, 1)
sns.histplot(df_no_id['avg_glucose_level'], bins=30, kde=True, color='blue')
plt.title('Distribution of Avg Glucose Level')

# Histogram for bmi
plt.subplot(1, 2, 2)
sns.histplot(df_no_id['bmi'], bins=30, kde=True, color='green')
plt.title('Distribution of BMI')

plt.show()
